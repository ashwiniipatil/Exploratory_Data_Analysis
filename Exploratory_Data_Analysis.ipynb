# %% [markdown]
# # Exploratory Data Analysis

# %%
#load the libraries
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
data = pd.read_csv("data_clean.csv")# reading csv file
data.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
# box=data.boxplot(figsize=(5,5))

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.tail(10)
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 149   30.0    193.0   6.9     70     9   26  2010    70       C
# 150    NaN    145.0  13.2     77     9   27  2010    77      PS
# 151   14.0    191.0  14.3     75     9   28  2010    75       S
# 152   18.0    131.0   8.0     76     9   29  2010    76      PS
# 153   20.0    223.0  11.5     68     9   30  2010    68       S
# 154   41.0    190.0   7.4     67     5    1  2010    67       C
# 155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156    NaN    145.0  13.2     77     9   27  2010    77       S
# 157   14.0    191.0  14.3     75     9   28  2010    75       S
# 158   18.0    131.0   8.0     76     9   29  2010    76       C

# %%
#Data Structure 
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
#data types
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %% [markdown]
# ### This is comment

# %% [markdown]
# # Data type conversion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 1 to 158
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.3+ KB

# %%
data['Month'].isnull().sum()
# Out:
# 0

# %%
data['Ozone'].isnull().sum()
# Out:
# 38

# %%
data['Month'].head(25)
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 3     5.0
# 4     5.0
# 5     5.0
# 6     5.0
# 7     5.0
# 8     5.0
# 9     5.0
# 10    5.0
# 11    5.0
# 12    5.0
# 13    5.0
# 14    5.0
# 15    5.0
# 16    5.0
# 17    5.0
# 18    5.0
# 19    5.0
# 20    5.0
# 21    5.0
# 22    5.0
# 23    NaN
# 24    5.0
# Name: Month, dtype: float64

# %%
# following line will show an error
# data['Month']=pd.to_numeric(data['Month'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "May"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3696\494300973.py in <module>
# ----> 1 data['Month']=pd.to_numeric(data['Month'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "May" at position 23

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce') #[1,1.5,NAN] january NA
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')# coerce will introduce NA values for non numeric data in the columns
data['Weather']=data['Weather'].astype('category')           #data['Wind']=data['Wind'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      157 non-null    float64
#  5   Month       157 non-null    float64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    category
# dtypes: category(1), float64(5), int64(4)
# memory usage: 11.5 KB

# %% [markdown]
# ####More on data type conversions
# [link text](https://stackoverflow.com/questions/15891038/change-column-type-in-pandas)

# %% [markdown]
# # Duplicates

# %%
data.duplicated().head(40)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
#Count of duplicated rows
data[data.duplicated()].shape
# Out:
# (0, 10)

# %%
data
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 1     41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 2     36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 3     12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 4     18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 5      NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#Print the duplicated rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
data_cleaned1=data.drop_duplicates()

# %%
data_cleaned1.shape
# Out:
# (158, 10)

# %% [markdown]
# # Drop columns

# %%
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    67.0    5.0    1  2010    67       S
# 1             2   36.0    118.0   8.0    72.0    5.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    74.0    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    62.0    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    56.0    5.0    5  2010    56       S
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    67.0    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    70.0    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    77.0    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    75.0    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    76.0    9.0   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data_cleaned2=data_cleaned1.drop('Temp C',axis=1)

# %%
data_cleaned2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0    118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0    313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN      NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...      ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN    145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0    191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# # Rename the columns

# %%
#rename the Solar column
data_cleaned3 = data_cleaned2.rename({'Solar.R': 'Solar'}, axis=1)

# %%
data_cleaned3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4    5.0    1  2010    67       S
# 1             2   36.0  118.0   8.0    5.0    2  2010    72       C
# 2             3   12.0  149.0  12.6    5.0    3  2010    74      PS
# 3             4   18.0  313.0  11.5    5.0    4  2010    62       S
# 4             5    NaN    NaN  14.3    5.0    5  2010    56       S
# ..          ...    ...    ...   ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4    5.0    1  2010    67       C
# 154         155   30.0  193.0   6.9    9.0   26  2010    70      PS
# 155         156    NaN  145.0  13.2    9.0   27  2010    77       S
# 156         157   14.0  191.0  14.3    9.0   28  2010    75       S
# 157         158   18.0  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# # Missing Values and Imputation

# %%
cols = data_cleaned3.columns 
cols
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Year', 'Temp',
#        'Weather'],
#       dtype='object')

# %%
import seaborn as sns
cols = data_cleaned3.columns 
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_cleaned3[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 4            5    NaN    NaN  14.3    5.0    5  2010    56       S
# 5            6   28.0    NaN  14.9    5.0    6  2010    66       C
# 9           10    NaN  194.0   8.6    5.0   10  2010    69       S
# 10          11    7.0    NaN   6.9    5.0   11  2010    74       C
# 23          24   32.0   92.0  12.0    NaN   24  2010    61       C

# %%
data_cleaned3.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Month          1
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
data_cleaned3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 1 to 158
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    category
# dtypes: category(1), float64(4), int64(3)
# memory usage: 10.1 KB

# %%
data_cleaned3['Ozone'].mean()
# Out:
# 41.583333333333336

# %%
#Mean Imputationa
m = data_cleaned3['Ozone'].mean()
print(m)
# Out:
# 41.583333333333336

# %%
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(m)

# %%
data_cleaned3['Ozone'].isnull().sum()
# Plot boxplot
# Out:
# 0

# %%
#Missing value imputation for categorical vlaue
#Get the object columns
obj_columns=data_cleaned3[['Weather']]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
z=obj_columns.mode().iloc[0]

# %%
z
# Out:
# Weather    S
# Name: 0, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
#Missing value imputation for categorical value
# df.mode
# df.median//////
obj_columns=obj_columns.fillna(z)
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data_cleaned3.boxplot()
# Out:
# <AxesSubplot:>

# %%
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
obj_columns.shape
# Out:
# (157, 1)

# %%
#data_cleaned4=data_cleaned3.drop(['Weather'],axis=1,inplace=True)

# %%
#Join the data set with imputed object dataset
data_cleaned4=pd.concat([data_cleaned3,obj_columns],axis=1)

# %%
data_cleaned4.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       3
# Weather       0
# dtype: int64

# %%
data_cleaned4
# Out:
#          Ozone  Solar  Wind  Month  Day  Year  Temp Weather Weather
# 1    41.000000  190.0   7.4    5.0    1  2010    67       S       S
# 2    36.000000  118.0   8.0    5.0    2  2010    72       C       C
# 3    12.000000  149.0  12.6    5.0    3  2010    74      PS      PS
# 4    18.000000  313.0  11.5    5.0    4  2010    62       S       S
# 5    41.815126    NaN  14.3    5.0    5  2010    56       S       S
# ..         ...    ...   ...    ...  ...   ...   ...     ...     ...
# 153  20.000000  223.0  11.5    9.0   30  2010    68       S       S
# 154  41.000000  190.0   7.4    5.0    1  2010    67       C       C
# 155  30.000000  193.0   6.9    9.0   26  2010    70      PS      PS
# 156  41.815126  145.0  13.2    9.0   27  2010    77       S       S
# 158  18.000000  131.0   8.0    9.0   29  2010    76       C       C
#
# [157 rows x 9 columns]

# %%
#Bar plot
data['Weather'].value_counts().plot.bar()

# %% [markdown]
# # Outlier Detection

# %%
# histogram of Ozone
data_cleaned3['Ozone'].hist()
# Out:
# <AxesSubplot:>

# %%
#Box plot
import matplotlib.pyplot as plt
data_box=data_cleaned3.dropna()
data1_box=data_box.Ozone
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19fca4c2b80>,
#   <matplotlib.lines.Line2D at 0x19fca4c2e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x19fca4d4160>,
#   <matplotlib.lines.Line2D at 0x19fca4d4430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19fca4c28b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19fca4d4700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19fca4d4970>],
#  'means': []}

# %%
dir(data_box)
# Out:
# ['Day',
#  'Month',
#  'Ozone',
#  'Solar',
#  'T',
#  'Temp',
#  'Weather',
#  'Wind',
#  'Year',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
#Extracting outliers
box=plt.boxplot(data['Ozone'].dropna())

# %%
type(box)
for i,j in box.items():
  print(i,j)
# Out:
# whiskers [<matplotlib.lines.Line2D object at 0x7f8f19120bb0>, <matplotlib.lines.Line2D object at 0x7f8f19120f10>]
# caps [<matplotlib.lines.Line2D object at 0x7f8f1912c2b0>, <matplotlib.lines.Line2D object at 0x7f8f1912c610>]
# boxes [<matplotlib.lines.Line2D object at 0x7f8f19120850>]
# medians [<matplotlib.lines.Line2D object at 0x7f8f1912c970>]
# fliers [<matplotlib.lines.Line2D object at 0x7f8f1912cc70>]
# means []

# %%
[item.get_ydata() for item in box['fliers']] #fliers are outliers
# Out:
# [array([135., 168.])]

# %%
#To get the whiskers
[item.get_ydata()[1] for item in box['whiskers']]
# Out:
# [1.0, 122.0]

# %%
#Descriptive stat
data_cleaned3['Ozone'].describe()
# Out:
# count    157.000000
# mean      41.815126
# std       28.404353
# min        1.000000
# 25%       21.000000
# 50%       41.815126
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %% [markdown]
# # Scatter plot and Correlation analysis

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
pd.plotting.scatter_matrix(data_cleaned3)
sns.pairplot(data_cleaned3)
# Out:
# C:\Users\askpr\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:100: UserWarning: Attempting to set identical left == right == 2010.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\askpr\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical bottom == top == 2010.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\askpr\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:91: UserWarning: Attempting to set identical left == right == 2010.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
data_cleaned3.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar         7
# Wind          0
# Month         1
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
#Correlation
data_cleaned3.corr()
# Out:
#             Unnamed: 0     Ozone     Solar      Wind     Month       Day  \
# Unnamed: 0    1.000000  0.111910 -0.109520 -0.158309  0.949690  0.216219
# Ozone         0.111910  1.000000  0.307253 -0.523806  0.123962 -0.030241
# Solar        -0.109520  0.307253  1.000000 -0.056594 -0.092918 -0.154212
# Wind         -0.158309 -0.523806 -0.056594  1.000000 -0.153507  0.040151
# Month         0.949690  0.123962 -0.092918 -0.153507  1.000000  0.061236
# Day           0.216219 -0.030241 -0.154212  0.040151  0.061236  1.000000
# Year               NaN       NaN       NaN       NaN       NaN       NaN
# Temp          0.337537  0.606275  0.273322 -0.441247  0.393321 -0.124538
#
#             Year      Temp
# Unnamed: 0   NaN  0.337537
# Ozone        NaN  0.606275
# Solar        NaN  0.273322
# Wind         NaN -0.441247
# Month        NaN  0.393321
# Day          NaN -0.124538
# Year         NaN       NaN
# Temp         NaN  1.000000

# %% [markdown]
# # Transformations

# %% [markdown]
# #### Dummy Variable

# %%
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp Weather
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67       S
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72       C
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74      PS
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62       S
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56       S
# ..          ...        ...    ...   ...    ...  ...   ...   ...     ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67       C
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70      PS
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77       S
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75       S
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
#Creating dummy variable for Weather column
data_cleaned4=pd.get_dummies(data_cleaned3,columns=['Weather'])

# %%
data_cleaned4
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Month  Day  Year  Temp  Weather_C  \
# 0             1  41.000000  190.0   7.4    5.0    1  2010    67          0
# 1             2  36.000000  118.0   8.0    5.0    2  2010    72          1
# 2             3  12.000000  149.0  12.6    5.0    3  2010    74          0
# 3             4  18.000000  313.0  11.5    5.0    4  2010    62          0
# 4             5  41.583333    NaN  14.3    5.0    5  2010    56          0
# ..          ...        ...    ...   ...    ...  ...   ...   ...        ...
# 153         154  41.000000  190.0   7.4    5.0    1  2010    67          1
# 154         155  30.000000  193.0   6.9    9.0   26  2010    70          0
# 155         156  41.583333  145.0  13.2    9.0   27  2010    77          0
# 156         157  14.000000  191.0  14.3    9.0   28  2010    75          0
# 157         158  18.000000  131.0   8.0    9.0   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0             0          1
# 1             0          0
# 2             1          0
# 3             0          1
# 4             0          1
# ..          ...        ...
# 153           0          0
# 154           1          0
# 155           0          1
# 156           0          1
# 157           0          0
#
# [158 rows x 11 columns]

# %%
data_cleaned4=data_cleaned4.dropna()

# %% [markdown]
# #### Normalization of the data

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values
# Out:
# array([[  1.        ,  41.        , 190.        , ...,   0.        ,
#           0.        ,   1.        ],
#        [  2.        ,  36.        , 118.        , ...,   1.        ,
#           0.        ,   0.        ],
#        [  3.        ,  12.        , 149.        , ...,   0.        ,
#           1.        ,   0.        ],
#        ...,
#        [156.        ,  41.58333333, 145.        , ...,   0.        ,
#           0.        ,   1.        ],
#        [157.        ,  14.        , 191.        , ...,   0.        ,
#           0.        ,   1.        ],
#        [158.        ,  18.        , 131.        , ...,   1.        ,
#           0.        ,   0.        ]])

# %%
array = data_cleaned4.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.   0.24 0.56 0.3  0.   0.   0.   0.25 0.   0.   1.  ]
#  [0.01 0.21 0.34 0.33 0.   0.03 0.   0.38 1.   0.   0.  ]
#  [0.01 0.07 0.43 0.57 0.   0.07 0.   0.43 0.   1.   0.  ]
#  [0.02 0.1  0.94 0.52 0.   0.1  0.   0.12 0.   0.   1.  ]
#  [0.04 0.13 0.89 0.36 0.   0.2  0.   0.2  0.   1.   0.  ]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler()
scaler.fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[-1.78 -0.02  0.04 -0.74 -1.47 -1.71  0.   -1.22 -0.65 -0.67  1.28]
#  [-1.76 -0.2  -0.77 -0.57 -1.47 -1.6   0.   -0.67  1.53 -0.67 -0.78]
#  [-1.73 -1.03 -0.42  0.75 -1.47 -1.49  0.   -0.45 -0.65  1.5  -0.78]
#  [-1.71 -0.82  1.44  0.43 -1.47 -1.38  0.   -1.78 -0.65 -0.67  1.28]
#  [-1.65 -0.65  1.28 -0.4  -1.47 -1.04  0.   -1.45 -0.65  1.5  -0.78]]

# %% [markdown]
# # Speed up the EDA process

# %%
# !pip install pandas-profiling==3.1.0
# !pip install sweetviz
# Out:
# Collecting pandas-profiling==3.1.0
#   Downloading pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
#      -------------------------------------- 261.2/261.2 kB 4.0 MB/s eta 0:00:00
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (0.11.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (3.5.2)
# Collecting tangled-up-in-unicode==0.1.0
#   Downloading tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
#      ---------------------------------------- 3.1/3.1 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (3.1.2)
# Collecting multimethod>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (1.21.5)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.4/102.4 kB 5.8 MB/s eta 0:00:00
# Collecting phik>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
#      -------------------------------------- 663.5/663.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (6.0)
# Collecting joblib~=1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      -------------------------------------- 303.1/303.1 kB 3.1 MB/s eta 0:00:00
# Collecting pydantic>=1.8.1
#   Downloading pydantic-2.0.3-py3-none-any.whl (364 kB)
#      -------------------------------------- 364.0/364.0 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (2.0.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (4.64.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (1.9.1)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (1.4.4)
# Requirement already satisfied: requests>=2.24.0 in c:\users\askpr\anaconda3\lib\site-packages (from pandas-profiling==3.1.0) (2.28.1)
# Requirement already satisfied: networkx>=2.4 in c:\users\askpr\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\askpr\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (21.4.0)
# Requirement already satisfied: Pillow in c:\users\askpr\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (9.2.0)
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      -------------------------------------- 296.5/296.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling==3.1.0) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.1.0) (2022.1)
# Collecting typing-extensions>=4.6.1
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.3.0
#   Downloading pydantic_core-2.3.0-cp39-none-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\askpr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\askpr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\askpr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\askpr\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling==3.1.0) (1.26.11)
# Requirement already satisfied: colorama in c:\users\askpr\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling==3.1.0) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\askpr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling==3.1.0) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\askpr\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling==3.1.0) (1.3.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=5c24882588b659ceb5fead62cc89f3da296f087d8fb3ab8c04573098816376c1
#   Stored in directory: c:\users\askpr\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, typing-extensions, tangled-up-in-unicode, multimethod, joblib, annotated-types, pydantic-core, imagehash, visions, pydantic, phik, missingno, pandas-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# Successfully installed annotated-types-0.5.0 htmlmin-0.1.12 imagehash-4.3.1 joblib-1.0.1 missingno-0.5.2 multimethod-1.9.1 pandas-profiling-3.1.0 phik-0.12.3 pydantic-2.0.3 pydantic-core-2.3.0 tangled-up-in-unicode-0.1.0 typing-extensions-4.7.1 visions-0.7.4
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
#      ---------------------------------------- 15.1/15.1 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (1.9.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (1.4.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (3.5.2)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\askpr\anaconda3\lib\site-packages (from sweetviz) (1.21.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\askpr\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\askpr\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\askpr\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\askpr\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.1)
# Requirement already satisfied: colorama in c:\users\askpr\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\askpr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-6.0.0 sweetviz-2.1.4

# %%
import pandas_profiling as pp
import sweetviz as sv
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6456\326613757.py in <module>
# ----> 1 import pandas_profiling as pp
#       2 import sweetviz as sv
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# ~\anaconda3\lib\site-packages\pandas_profiling\controller\pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in <module>
#      11 from visions import VisionsTypeset
#      12
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.alerts import AlertType
#
# ~\anaconda3\lib\site-packages\pandas_profiling\config.py in <module>
#       4
#       5 import matplotlib
# ----> 6 from pydantic import BaseModel, BaseSettings, Field
#       7
#       8 matplotlib.use("Agg")
#
# ~\anaconda3\lib\site-packages\pydantic\__init__.py in __getattr__(attr_name)
#     205     dynamic_attr = _dynamic_imports.get(attr_name)
#     206     if dynamic_attr is None:
# --> 207         return _getattr_migration(attr_name)
#     208
#     209     from importlib import import_module
#
# ~\anaconda3\lib\site-packages\pydantic\_migration.py in wrapper(name)
#     286             return import_string(REDIRECT_TO_V1[import_path])
#     287         if import_path == 'pydantic:BaseSettings':
# --> 288             raise PydanticImportError(
#     289                 '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     290                 f'See https://docs.pydantic.dev/{VERSION}/migration/#basesettings-has-moved-to-pydantic-settings '
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.0.3/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.0.3/u/import-error

# %%
EDA_report= pp.ProfileReport(data)
EDA_report.to_file(output_file='report2.html')

# %%
sweet_report = sv.analyze(data)
sweet_report.show_html('weather_report.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6456\73649713.py in <module>
# ----> 1 sweet_report = sv.analyze(data)
#       2 sweet_report.show_html('weather_report.html')
#
# NameError: name 'sv' is not defined

# %%
from scipy import stats
#stats.norm.cdf(z)
t=2.236
1-stats.t.cdf(t,df=80)
# Out:
# 0.014068761577990418
